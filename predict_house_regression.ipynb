# %% [markdown]
# # A. Get Data

# %%
import pandas as pd

df = pd.read_csv("/kaggle/input/competitions/predict-housing-price/estate_train.csv")
text = pd.read_csv("/kaggle/input/competitions/predict-housing-price/estate_test.csv")
