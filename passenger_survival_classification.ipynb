# %% [markdown]
# ## A. Get Data

# %%
import pandas as pd

df = pd.read_csv("/kaggle/input/competitions/predict-survival-of-the-passengers/maritime_train.csv")
test = pd.read_csv("/kaggle/input/competitions/predict-survival-of-the-passengers/maritime_test.csv")

# %% [markdown]
# # B. EDA
